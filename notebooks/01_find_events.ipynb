# %% [markdown]
# # 01 — Find Coincident Events
#
# Query the STIX flare catalog and MWA observation database for overlapping solar burst events.

# %%
import pandas as pd
from astropy.time import Time

# %% [markdown]
# ## STIX flare catalog

# %%
# Query STIX flare list
# https://datacenter.stix.i4ds.net/

# %% [markdown]
# ## MWA observation database

# %%
# Query MWA TAP service for observations overlapping STIX flare times

# %% [markdown]
# ## Coincident events

# %%
# Cross-match and save results to data/coincident_events.csv
