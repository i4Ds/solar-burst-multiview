# %% [markdown]
# # 04 — Multi-wavelength View
#
# Combine STIX X-ray light curves, e-Callisto dynamic spectra, and MWA radio images for a single event.

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from astropy.time import Time

# %% [markdown]
# ## Load data

# %%
# Load STIX light curve
# Load eCallisto spectrum
# Load MWA image

# %% [markdown]
# ## Combined figure

# %%
fig = plt.figure(figsize=(14, 10))
gs = gridspec.GridSpec(3, 2)

# ax_stix     = fig.add_subplot(gs[0, :])
# ax_callisto = fig.add_subplot(gs[1, :])
# ax_mwa      = fig.add_subplot(gs[2, 0])
# ax_overlay  = fig.add_subplot(gs[2, 1])
